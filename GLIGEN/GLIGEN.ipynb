# %%
# !git clone https://github.com/MahdiGolizadeh/Layout2Image.git
# Out:
# Cloning into 'Layout2Image'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 188 (delta 51), reused 186 (delta 49), pack-reused 0 (from 0)
# Receiving objects: 100% (188/188), 17.27 MiB | 20.02 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# !mv /content/Layout2Image/GLIGEN/* /content/
# !rmdir /content/Layout2Image/GLIGEN

# %%
# !pip install albumentations
# !pip install opencv-python
# !pip install pudb
# !pip install imageio
# !pip install imageio-ffmpeg
# !pip install pytorch-lightning
# !pip install omegaconf
# !pip install test-tube
# !pip install streamlit
# !pip install einops
# !pip install torch-fidelity
# !pip install git+https://github.com/openai/CLIP.git
# !pip install protobuf
# !pip install torchmetrics
# !pip install transformers
# !pip install kornia
# !pip uninstall -y torchtext
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 128.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 32.3 MB/s eta 0:00:00
# ...
#   Created wheel for urwid-readline: filename=urwid_readline-0.15.1-py3-none-any.whl size=9322 sha256=fc0e4d9ad60756825aade8a0cf2e8fad6d7d9bc7f92911b4dc60a7bc374da26f
#   Stored in directory: /root/.cache/pip/wheels/7c/9f/91/6658ca67972b70a9d89fabda634a2941c40025910040d0014b
# Successfully built urwid-readline
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 64.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 75.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
import os

checkpoint_dir = '/content/gligen_checkpoints'

# Create folder if it doesn't exist
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
    print(f"Created directory: {checkpoint_dir}")

# Download using wget
# !wget -P {checkpoint_dir} https://huggingface.co/gligen/gligen-generation-text-box/resolve/main/diffusion_pytorch_model.bin

print(f"File downloaded to: {checkpoint_dir}")
# Out:
# Created directory: /content/gligen_checkpoints
# --2026-06-24 16:32:59--  https://huggingface.co/gligen/gligen-generation-text-box/resolve/main/diffusion_pytorch_model.bin
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.34, 13.35.202.121, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.aws.cdn.hf.co/xet-bridge-us/640381e3eec7c32754e7c461/5f5b08a706393285200a787e48d02ac35411727aa7a47c68bb9716c19598d14e?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27diffusion_pytorch_model.bin%3B+filename%3D%22diffusion_pytorch_model.bin%22%3B&user_id=public&response-content-type=application%2Foctet-stream&X-Xet-Cas-Uid=public&Expires=1782322379&Policy=..._&Signature=MEUCIQC0rK07PHMGACATRxfKqbQ522OpoV1nxYyliaEbKwnuwwIgDKz86Pyev%7EF55CZG5gD3mrBS3mpnCWb3GINblXjUFlw_&Key-Pair-Id=01KAYHXK2CBJSW0YZTMNXK9W1M [following]
# ...

# %%
import os

os.rename(
    "/content/gligen_checkpoints/diffusion_pytorch_model.bin",
    "/content/gligen_checkpoints/checkpoint_generation_text.pth"
)

# %%
# !python gligen_inference.py
# Out:
# 2026-06-24 16:55:45.031942: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# ...
# Loading weights: 100% 196/196 [00:00<00:00, 11463.84it/s]
# [transformers] CLIPTextModel LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                                            | Status     |  |
# ---------------------------------------------------------------+------------+--+-
# vision_model.encoder.layers.{0...23}.self_attn.v_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.layer_norm1.bias          | UNEXPECTED |  |
# ...
