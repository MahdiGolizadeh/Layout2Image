# %%
# !git clone https://github.com/MahdiGolizadeh/Layout2Image.git
# !mv /content/Layout2Image/MIGC/* /content/
# Out:
# Cloning into 'Layout2Image'...
# remote: Enumerating objects: 722, done.
# remote: Total 722 (delta 0), reused 0 (delta 0), pack-reused 722 (from 1)
# Receiving objects: 100% (722/722), 105.31 MiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
# !gdown 107fnQ9Fpu5K0UtqnHlKja7hqe-GwjAmz
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=107fnQ9Fpu5K0UtqnHlKja7hqe-GwjAmz
# From (redirected): https://drive.google.com/uc?id=107fnQ9Fpu5K0UtqnHlKja7hqe-GwjAmz&confirm=t&uuid=c6d6920a-2802-4e34-a655-c829432fd937
# To: /content/MIGC_SD14.ckpt
# 100% 230M/230M [00:03<00:00, 65.5MB/s]

# %%
# !mv /content/MIGC_SD14.ckpt /content/pretrained_weights/

# %%
# !gdown 1KI8Ih7SHISG9v9zRL1xhDIBsPjDHqPxI
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KI8Ih7SHISG9v9zRL1xhDIBsPjDHqPxI
# From (redirected): https://drive.google.com/uc?id=1KI8Ih7SHISG9v9zRL1xhDIBsPjDHqPxI&confirm=t&uuid=0ae26050-f5f7-4438-aea6-b4feaf617cf9
# To: /content/MIGC++_SD14.ckpt
# 100% 200M/200M [00:04<00:00, 45.2MB/s]

# %%
# !mv /content/MIGC++_SD14.ckpt /content/pretrained_weights/

# %%
# !pip install -qq -r requirement.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python migc_plus_inference_single_image.py
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2026-06-28 20:04:23.348313: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/migc/migc_pipeline.py:117: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(batch_size == 2, "We currently only implement sampling with batch_size=1, \
# /content/migc_plus/migc_plus_pipeline.py:118: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(batch_size == 2, "We currently only implement sampling with batch_size=1, \
# ...
