# %%
# !git clone https://github.com/MahdiGolizadeh/Layout2Image.git
# !mv /content/Layout2Image/HiCo/* /content/
# Out:
# Cloning into 'Layout2Image'...
# remote: Enumerating objects: 1489, done.
# remote: Counting objects: 100% (767/767), done.
# remote: Compressing objects: 100% (497/497), done.
# remote: Total 1489 (delta 285), reused 729 (delta 252), pack-reused 722 (from 1)
# Receiving objects: 100% (1489/1489), 121.82 MiB | 22.05 MiB/s, done.
# Resolving deltas: 100% (495/495), done.
# Updating files: 100% (1161/1161), done.

# %%
# !pip install -r requirements.txt

# %%
# !rm -rf models/controlnet
# !git clone https://huggingface.co/qihoo360/HiCo_T2I models/controlnet
# Out:
# Cloning into 'models/controlnet'...
# remote: Enumerating objects: 46, done.
# remote: Total 46 (delta 0), reused 0 (delta 0), pack-reused 46 (from 1)
# Receiving objects: 100% (46/46), 17.33 KiB | 17.33 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# !git clone https://huggingface.co/krnl/realisticVisionV51_v51VAE
# Out:
# Cloning into 'realisticVisionV51_v51VAE'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 28 (delta 0), reused 0 (delta 0), pack-reused 27 (from 1)
# Receiving objects: 100% (28/28), 516.56 KiB | 12.01 MiB/s, done.
# Filtering content: 100% (5/5), 9.07 GiB | 41.26 MiB/s, done.

# %%
# !mv /content/realisticVisionV51_v51VAE/*  /content/models/realisticVisionV51_v51VAE

# %%
# !CUDA_VISIBLE_DEVICES=0 python infer-avg.py
# Out:
# /content/diffusers/src/diffusers/pipelines/deepfloyd_if/pipeline_if.py:102: SyntaxWarning: invalid escape sequence '\)'
#   r"[" + "#®•©™&@·º½¾¿¡§~" + "\)" + "\(" + "\]" + "\[" + "\}" + "\{" + "\|" + "\\" + "\/" + "\*" + r"]{1,}"
# /content/diffusers/src/diffusers/pipelines/deepfloyd_if/pipeline_if.py:102: SyntaxWarning: invalid escape sequence '\('
#   r"[" + "#®•©™&@·º½¾¿¡§~" + "\)" + "\(" + "\]" + "\[" + "\}" + "\{" + "\|" + "\\" + "\/" + "\*" + r"]{1,}"
# /content/diffusers/src/diffusers/pipelines/deepfloyd_if/pipeline_if.py:102: SyntaxWarning: invalid escape sequence '\]'
#   r"[" + "#®•©™&@·º½¾¿¡§~" + "\)" + "\(" + "\]" + "\[" + "\}" + "\{" + "\|" + "\\" + "\/" + "\*" + r"]{1,}"
# /content/diffusers/src/diffusers/pipelines/deepfloyd_if/pipeline_if.py:102: SyntaxWarning: invalid escape sequence '\['
#   r"[" + "#®•©™&@·º½¾¿¡§~" + "\)" + "\(" + "\]" + "\[" + "\}" + "\{" + "\|" + "\\" + "\/" + "\*" + r"]{1,}"
# ...
