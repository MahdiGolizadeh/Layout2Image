# %%
# !git clone https://github.com/MahdiGolizadeh/Layout2Image.git
# Out:
# Cloning into 'Layout2Image'...
# remote: Enumerating objects: 537, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 537 (delta 59), reused 215 (delta 55), pack-reused 313 (from 1)
# Receiving objects: 100% (537/537), 76.85 MiB | 16.52 MiB/s, done.
# Resolving deltas: 100% (134/134), done.
# Updating files: 100% (429/429), done.

# %%
# !mv /content/Layout2Image/GeoDiffusion/* /content/

# %%
# !pip install -qq -r /content/requirements/dev.txt
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for mmpycocotools
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (mmpycocotools)

# %%
# !pip install bbox_visualizer

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="KaiChen1998/geodiffusion-nuimages-256x256",
    local_dir="/content/GeoDiffusion/geodiffusion-nuimages-256x256",
    local_dir_use_symlinks=False
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# ...

# %%
# !python run_layout_to_image.py /content/GeoDiffusion/geodiffusion-nuimages-256x256 --output_dir /content/results/
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]An error occurred while trying to fetch /content/GeoDiffusion/geodiffusion-nuimages-256x256/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /content/GeoDiffusion/geodiffusion-nuimages-256x256/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Loading pipeline components...:  29% 2/7 [00:01<00:04,  1.02it/s]An error occurred while trying to fetch /content/GeoDiffusion/geodiffusion-nuimages-256x256/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /content/GeoDiffusion/geodiffusion-nuimages-256x256/vae.
# ...
