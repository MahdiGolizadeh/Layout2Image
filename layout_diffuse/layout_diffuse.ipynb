# %%
# !git clone https://github.com/MahdiGolizadeh/Layout2Image.git
# Out:
# Cloning into 'Layout2Image'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 325 (delta 1), reused 7 (delta 1), pack-reused 313 (from 1)
# Receiving objects: 100% (325/325), 51.56 MiB | 25.42 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Updating files: 100% (272/272), done.

# %%
# !mv /content/Layout2Image/layout_diffuse/* /content/
# !rmdir /content/Layout2Image/layout_diffuse

# %%
# !pip install -qq -r requirements.txt
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.7/116.7 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.3/338.3 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 54.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.1 MB/s eta 0:00:00

# %%
# !gdown https://huggingface.co/cplusx/LD/resolve/main/LD_SD2_1.ckpt
# Out:
# Downloading...
# From: https://huggingface.co/cplusx/LD/resolve/main/LD_SD2_1.ckpt
# To: /content/LD_SD2_1.ckpt
# 100% 5.75G/5.75G [02:08<00:00, 44.6MB/s]

# %%
# !python generate_from_layout.py \
  -c configs/cocostuff_SD2_1.json \
  --model_path /content/LD_SD2_1.ckpt \
  --layout_json '[{"bbox":[0.10,0.15,0.28,0.65],"class":"person"},{"bbox":[0.55,0.52,0.30,0.25],"class":"dog"},{"bbox":[0.05,0.70,0.35,0.20],"class":"bench"}]' \
  --image_width 512 \
  --image_height 512 \
  --output_dir outputs/my_layout_test \
  --output_name person_dog_bench
# Out:
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# open_clip_model.safetensors: 100% 3.94G/3.94G [01:13<00:00, 53.7MB/s]
# /content/DDIM_ldm/DDIM_ldm.py:136: SyntaxWarning: invalid escape sequence '\h'
#   \hat(y_0) = 1 / sqrt[\bar(a)]*y_t - sqrt[(1-\bar(a)) / \bar(a)]*noise'''
# /content/DDIM_ldm/DDIM_ldm.py:155: SyntaxWarning: invalid escape sequence '\h'
#   ''' predict y_{t-1} from \hat(y_0) and y_t. Eq(7) in DDPM paper
# WARNING: cannot find pretrained_models/SD2_1/unet.ckpt, skip initialization
# ...
# WARNING: pretrained_models/SD2_1/clip.ckpt does not exist, text model is not initialized
# INFO: loading checkpoint
# /content/LD_SD2_1.ckpt
# INFO: Found checkpoint /content/LD_SD2_1.ckpt
# INFO: using default caption:
#  person, dog, bench
# Data shape for PLMS sampling is (1, 4, 64, 64)
# Running PLMS Sampling with 20 timesteps
# ...
